# %%
# %load_ext autoreload
# %autoreload 2

from semantic_parser.modules.verdant.actions import *
from semantic_parser.modules.verdant.openai_utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# FetchRelatedColumns
import os

client = OpenAIUtils(api_key=os.getenv("AZURE_OPENAI_API_KEY"))
db_manager = DatabaseManager(
    visible_tables=[
        "FundCashFlow",
        "FundInvestmentProperties",
        "FundInvestmentTimeProperties",
        "FundTimeProperties",
        "HandTransformedPortfolioInvestmentswithCFRaw"
    ]
)

fetch_column = FetchRelatedColumns(openai_client=client)
fetch_knowledge = FetchBackgroundKnowledge(openai_client=client)
sketch_sql = SketchSQL(openai_client=client)
generate_sql = GenerateSQL(openai_client=client)
execute_sql = ExecuteSQL(db_manager=db_manager)

# %%
def dict_to_string(d, separator=' '):
    """
    Flatten a nested dictionary of strings into a single string.
    
    Args:
        d: Dictionary (possibly nested) containing strings
        separator: String to join values with (default: ' ')
    
    Returns:
        Single concatenated string
    """
    result = []
    
    def flatten(obj):
        if isinstance(obj, dict):
            for value in obj.values():
                flatten(value)
        elif isinstance(obj, str):
            result.append(obj)
        elif isinstance(obj, (list, tuple)):
            for item in obj:
                flatten(item)
    
    flatten(d)
    return separator.join(result)

# %%
result = {
    "query": "On a year-on-year basis (4Q24 vs 4Q23), which funds saw an uplift to overall MOIC (i.e., Fund MOIC) in 2024?"
}
output = fetch_column.execute(**result)
result = output.result
print(result)
# Out:
# {'approach': 'Derive each fund’s MOIC at the end of 4Q-2023 and at the end of 4Q-2024 from the quarterly investment-level table, then keep only those funds whose 2024 figure is higher than 2023. Return the fund identifiers (and optionally both MOIC figures and the uplift delta).', 'sketch': '1. From FundInvestmentTimeProperties keep only the two quarter-end records we care about – the rows whose quarter_date (or fiscal_quarter column) equals 2023-12-31 (4Q23) or 2024-12-31 (4Q24).\n2. Aggregate those rows to the fund level because each fund has many portfolio-company rows.  For each fund+quarter, add up cost_basis (capital_invested) and total_value (realised_value + unrealised_value) and then compute fund_MOIC = total_value / cost_basis.  If there is already a pre-calculated MOIC column, simply take MAX(MOIC) instead of re-computing.\n3. Pivot the two quarters into separate columns so that every fund is now one row that holds moic_4q23 and moic_4q24.  The easiest way is to self-join the aggregated data (or use conditional aggregation).\n4. Compare the two numbers.  Keep only rows where moic_4q24 > moic_4q23 (strict uplift) or ≥ if you want flat counts included.\n5. Select and return the fund_id and the two MOIC columns (and optionally the delta) ordered by the size of the increase, if desired.', 'key_operations': ['WHERE filter on quarter / date to keep 4Q23 and 4Q24', 'GROUP BY fund_id, quarter_end_date to aggregate investment rows', 'SUM of cost and value, or MAX of existing MOIC column', 'Computed column or CASE aggregation to pivot quarters', 'JOIN (or conditional aggregation) to put 2023 and 2024 numbers side by side', 'HAVING clause to keep funds where 2024 MOIC > 2023 MOIC', 'ORDER BY uplift (optional)'], 'columns_needed': {'FundInvestmentTimeProperties': ['FundID', 'QuarterEndDate  (or FiscalQuarter)', 'CostBasis or InvestedCapital', 'TotalValue (RealizedValue + UnrealizedValue)  OR pre-calculated MOIC column']}, 'potential_challenges': ['Quarter end column names may differ (e.g., CalendarQuarter, FiscalQuarter, QuarterLabel) and must map exactly to 2023-12-31 and 2024-12-31.', 'Some funds might be missing either 4Q23 or 4Q24 data; decide whether to exclude or treat missing MOIC as zero.', 'CostBasis can be zero for fully realised positions, leading to divide-by-zero; need NULLIF or filter such cases.', 'Currency or FX effects if tables mix currencies—ensure consistency before summing.', 'Duplicate rows or partial updates could inflate sums; verify that each investment-quarter row is unique.', 'If using a MOIC column directly, confirm it is already fund-level; otherwise compute from cost and value.'], 'sketch_length': 1017}

# %%
natural_language_sketch = dict_to_string(natural_language_sketch)
print(natural_language_sketch)
# Out:
# Compare fund-level MOIC at the end of 4Q24 with the value at the end of 4Q23 and return the funds whose MOIC increased. Step 1: Pull the position-level rows from FundInvestmentTimeProperties for quarter = '2024-12-31' (4Q24) and '2023-12-31' (4Q23). Step 2: For each fund in each quarter, aggregate to fund-level by summing TotalValue (realized + unrealized) and summing InvestedCost, then calculate MOIC = TotalValue / InvestedCost. Step 3: Place the two quarterly MOIC numbers side-by-side for every fund (self-join or conditional aggregation) so we have columns like moic_4q23 and moic_4q24. Step 4: Filter to funds where moic_4q24 > moic_4q23 (i.e., an uplift). Step 5: Return the fund identifier (and optionally the two MOIC values and the uplift amount/percentage) ordered by size of uplift or fund name. WHERE date filter for the two specific quarter-end dates GROUP BY fund_id, quarter to roll position rows up to fund level SUM for TotalValue and InvestedCost Computed column (TotalValue / InvestedCost) for MOIC JOIN or conditional aggregation to place 2023 and 2024 MOIC side-by-side Comparison filter (moic_4q24 > moic_4q23) ORDER BY (optional) FundID QuarterEndDate InvestedCost TotalValue Some funds might not have data for one of the two quarters; decide whether to exclude or treat missing MOIC as 0. Ensure InvestedCost is not zero to avoid divide-by-zero errors when calculating MOIC. MOIC field might already exist in the table; if so, use it directly and skip the cost/value aggregation calculation. Quarter column naming conventions could differ (e.g., Year, QuarterNo vs a single date field) and need translation to the exact date filter. Currency differences or restatements could cause apparent MOIC change; confirm values are in the same reporting currency.

# %%
kwargs_1 = {
    "natural_language_sketch": natural_language_sketch
}
output = generate_sql.execute(**kwargs_1)
sql_query = output.result['sql_query']
print(sql_query)
# Out:
# -- -------------------------------------------------------------------
# --  Compare fund-level MOIC at 4Q23 vs 4Q24 and return the funds whose
# --  MOIC improved.
# -- -------------------------------------------------------------------
# WITH quarterly_fund AS (
#     /*-----------------------------------------------------------------
#       Step 1 & 2 :  Pull position-level rows for the two quarter-ends,
#       aggregate them to fund level and calculate MOIC.
#       ----------------------------------------------------------------*/
#     SELECT
#         "FundID"                          AS fund_id,          -- fund identifier
#         "QuarterEndDate"                 AS quarter_end_date, -- e.g. 2023-12-31, 2024-12-31
#         SUM("TotalValue")   AS total_value,                   -- realised + unrealised
#         SUM("InvestedCost") AS invested_cost,
#         /* Protect against divide-by-zero */
#         SUM("TotalValue") / NULLIF(SUM("InvestedCost"),0) AS moic
#     FROM   "FundInvestmentTimeProperties"
#     WHERE  "QuarterEndDate" IN (DATE '2023-12-31', DATE '2024-12-31')
#     GROUP  BY "FundID", "QuarterEndDate"
# ),
# /*---------------------------------------------------------------------
#   Step 3 :  Pivot the two MOIC numbers into side-by-side columns.
# ---------------------------------------------------------------------*/
# moic_pivot AS (
#     SELECT
#         fund_id,
#         MAX(moic) FILTER (WHERE quarter_end_date = DATE '2023-12-31') AS moic_4q23,
#         MAX(moic) FILTER (WHERE quarter_end_date = DATE '2024-12-31') AS moic_4q24
#     FROM   quarterly_fund
#     GROUP  BY fund_id
# )
# /*---------------------------------------------------------------------
#   Step 4 & 5 :  Keep only funds with an uplift and return the details.
# ---------------------------------------------------------------------*/
# SELECT
#     fund_id,
#     moic_4q23,
#     moic_4q24,
#     moic_4q24 - moic_4q23                                           AS moic_uplift,
#     (moic_4q24 - moic_4q23) / NULLIF(moic_4q23,0)                  AS moic_uplift_pct
# FROM   moic_pivot
# WHERE  moic_4q24 > moic_4q23                   -- uplift filter
# ORDER  BY moic_uplift DESC, fund_id;           -- order by size of uplift

# %%
output.result
# Out:
# {'sql_query': '-- Step-1 & 2 :  roll position rows up to fund-level for the two quarter-ends\nWITH fund_quarter_moic AS (\n    SELECT  \n        "FundID",                               -- fund identifier\n        "QuarterEndDate",                      -- quarter-end date (should be 2023-12-31 or 2024-12-31)\n        SUM("TotalValue")     AS total_value,  -- realised + unrealised value\n        SUM("InvestedCost")   AS invested_cost,\n        /* protect against divide-by-zero */\n        CASE WHEN SUM("InvestedCost") = 0 THEN NULL\n             ELSE SUM("TotalValue")::numeric / SUM("InvestedCost") END AS moic\n    FROM   "FundInvestmentTimeProperties"\n    WHERE  "QuarterEndDate" IN ( DATE \'2023-12-31\', DATE \'2024-12-31\')\n    GROUP  BY "FundID", "QuarterEndDate"\n),\n-- Step-3 : place 4Q23 & 4Q24 MOIC side-by-side\nmoic_pivot AS (\n    SELECT \n        q24."FundID",\n        q23.moic AS moic_4q23,\n        q24.moic AS moic_4q24,\n        (q24.moic - q23.moic)                                  AS moic_uplift,\n        CASE WHEN q23.moic IS NULL OR q23.moic = 0 THEN NULL\n             ELSE (q24.moic - q23.moic) / q23.moic END         AS pct_uplift\n    FROM   fund_quarter_moic q24\n    JOIN   fund_quarter_moic q23\n           ON q24."FundID" = q23."FundID"\n          AND q23."QuarterEndDate" = DATE \'2023-12-31\'\n    WHERE  q24."QuarterEndDate" = DATE \'2024-12-31\'\n)\n-- Step-4 & 5 : keep funds whose MOIC increased and show results\nSELECT  \n    mp."FundID",\n    mp.moic_4q23,\n    mp.moic_4q24,\n    mp.moic_uplift,\n    mp.pct_uplift\nFROM   moic_pivot mp\nWHERE  mp.moic_4q24 > mp.moic_4q23      -- positive uplift only\nORDER  BY mp.moic_uplift DESC NULLS LAST, mp."FundID";',
#  'explanation': '1. Pulls position-level rows for 4Q23 (2023-12-31) and 4Q24 (2024-12-31) from FundInvestmentTimeProperties.\n2. Aggregates each quarter to fund-level: SUM(TotalValue) and SUM(InvestedCost); calculates MOIC = TotalValue / InvestedCost with divide-by-zero protection.\n3. Self-joins the aggregated data so each fund has MOIC_4Q23 and MOIC_4Q24 side-by-side (pivot).\n4. Filters to funds where MOIC_4Q24 is greater than MOIC_4Q23 (i.e., MOIC increased).\n5. Returns fund id, both MOICs, absolute uplift and percentage uplift, ordered by the size of the MOIC increase.'}
